# %%
#PCA
dims = [8,9,10,11,12,13]

aucroc_pca=[0.782706257068181,
 0.7806396840187928,
 0.8052609890248731,
 0.809085210291301,
 0.8106495657740069,
 0.8309395690511109]

# %%
#randomforest
aucroc_rf=[0.8638762741921417,
0.8644889853804564,
0.8639560798741793,
0.8628366216626365,
0.8668602229699592,
0.8668602229699592]

# %%
#LDA
trainlda = 10.30564022064209
predictlda = 0.2212681770324707
scorelda = 0.7825306111111903

# %%
#baseline
trainbase = 35.880000591278076
predictbase = 5.189058542251587
scorebase = 0.8765518000881588

# %%
#autoencoder
aucoencoder = [0.5584314306250645,
 0.5233651340070173,
 0.5366542309305742,
 0.5519790793306439,
 0.5644255907915235,
 0.5189487944294741]

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
x = dims
y1 = aucroc_pca
ax.plot(x,y1,label='PCA')
y2 = aucroc_rf
y3 = [0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903]
y4 = [0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588]
y5 = aucoencoder
ax.plot(x,y3,label='LDA')
ax.plot(x,y2,label='RF')
ax.plot(x,y4,label='baseline')
ax.plot(x,y5,label='AutoEncoder')

ax.set_xlabel('Dims')
ax.set_ylabel('AUC_ROC_SCORE')
ax.set_title('Results')
ax.legend()

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
x = dims
y1 = aucroc_pca
ax.plot(x,y1,label='PCA')
y2 = aucroc_rf
y3 = [0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903]
y4 = [0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588]
# y5 = aucoencoder
ax.plot(x,y3,label='LDA')
ax.plot(x,y2,label='RF')
ax.plot(x,y4,label='baseline')
# ax.plot(x,y5,label='AutoEncoder')

ax.set_xlabel('Dims')
ax.set_ylabel('AUC_ROC_SCORE')
ax.set_title('Results')
ax.legend()

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
x = dims
# y1 = aucroc_pca
# ax.plot(x,y1,label='PCA')
# y2 = aucroc_rf
# y3 = [0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903]
# y4 = [0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588]
y5 = aucoencoder
# ax.plot(x,y3,label='LDA')
# ax.plot(x,y2,label='RF')
# ax.plot(x,y4,label='baseline')
ax.plot(x,y5,label='AutoEncoder')

ax.set_xlabel('Dims')
ax.set_title('AUC_ROC_SCORE')
# ax.legend()
# Out:
# Text(0.5, 1.0, 'AUC_ROC_SCORE')

# %%
#autoencoder
auto_train_time=[4.51547908782959,
 4.142991542816162,
 4.456194877624512,
 4.850412607192993,
 5.224234104156494,
 4.8584816455841064]

# %%
#autoencoder
auto_predict_time=[0.6823995113372803,
 0.5583271980285645,
 0.6031877994537354,
 0.6246130466461182,
 0.6865365505218506,
 0.5922200679779053]

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
x = dims
# y1 = aucroc_pca
# ax.plot(x,y1,label='PCA')
# y2 = aucroc_rf
# y3 = [0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903]
# y4 = [0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588]
y5 = auto_train_time
# ax.plot(x,y3,label='LDA')
# ax.plot(x,y2,label='RF')
# ax.plot(x,y4,label='baseline')
ax.plot(x,y5,label='AutoEncoder')

ax.set_xlabel('Dims')
ax.set_title('Train_time')
# Out:
# Text(0.5, 1.0, 'Train_time')

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
x = dims
# y1 = aucroc_pca
# ax.plot(x,y1,label='PCA')
# y2 = aucroc_rf
# y3 = [0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903,0.7825306111111903]
# y4 = [0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588,0.8765518000881588]
y5 = auto_predict_time
# ax.plot(x,y3,label='LDA')
# ax.plot(x,y2,label='RF')
# ax.plot(x,y4,label='baseline')
ax.plot(x,y5,label='AutoEncoder')

ax.set_xlabel('Dims')
ax.set_title('Predict_time')
# Out:
# Text(0.5, 1.0, 'Predict_time')

# %%
#random forest
times_train_rf=[29.431183099746704,
 28.400020599365234,
 28.368229866027832,
 29.002838611602783,
 32.47084593772888,
 30.618134260177612]

times_predict_rf=[4.757906436920166,
 4.946686506271362,
 4.793347120285034,
 4.767031669616699,
 4.797030448913574,
 4.993752479553223]

# %%
#PCA
times_train_pca=[28.347519636154175,
 27.191433906555176,
 32.407042026519775,
 31.246403217315674,
 36.6754469871521,
 35.25782632827759]

times_pre_pca=[4.83068060874939,
 4.860852241516113,
 5.219556570053101,
 5.276562213897705,
 5.5862836837768555,
 5.1149561405181885]

# %%
#baseline
trainbase = 35.880000591278076
predictbase = 5.189058542251587
scorebase = 0.8765518000881588
#LDA
trainlda = 10.30564022064209
predictlda = 0.2212681770324707
scorelda = 0.7825306111111903

# %%
dims = [8,9,10,11,12,13]

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
x = dims
y1 = times_train_pca
ax.plot(x,y1,label='PCA')
y2 = times_train_rf
y3 = [10.30564022064209,10.30564022064209,10.30564022064209,10.30564022064209,10.30564022064209,10.30564022064209]
y4 = [35.880000591278076,35.880000591278076,35.880000591278076,35.880000591278076,35.880000591278076,35.880000591278076]
y5 = auto_train_time
ax.plot(x,y3,label='LDA')
ax.plot(x,y2,label='RF')
ax.plot(x,y4,label='baseline')
ax.plot(x,y5,label='AutoEncoder')

ax.set_xlabel('Dims')
ax.set_ylabel('Seconds')
ax.set_title('Training time')
ax.legend()

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
x = dims
y1 = times_pre_pca
ax.plot(x,y1,label='PCA')
y2 = times_predict_rf
y3 = [0.2212681770324707,0.2212681770324707,0.2212681770324707,0.2212681770324707,0.2212681770324707,0.2212681770324707]
y4 = [5.189058542251587,5.189058542251587,5.189058542251587,5.189058542251587,5.189058542251587,5.189058542251587]
y5 = auto_predict_time
ax.plot(x,y3,label='LDA')
ax.plot(x,y2,label='RF')
ax.plot(x,y4,label='baseline')
ax.plot(x,y5,label='AutoEncoder')

ax.set_xlabel('Dims')
ax.set_ylabel('Seconds')
ax.set_title('Predicting time')
ax.legend()
